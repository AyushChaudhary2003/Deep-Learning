# %%
# Step 1: Import Libraries
import torch
from torchvision import datasets, transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import sys

# Step 2: Set Up Kaggle Environment
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Step 3: Load and Preprocess the Dataset
data_transforms = transforms.Compose([
    transforms.Resize((32, 32)),  # CIFAR-10 images are 32x32
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=data_transforms)
val_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=data_transforms)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=128, shuffle=False)

# Step 4: Define the CNN Model
class CNN(nn.Module):
    def __init__(self, activation_func, weight_init):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 8 * 8, 128)  # Adjusted for 32x32 input
        self.fc2 = nn.Linear(128, 10)  # 10 classes for CIFAR-10
        
        # Weight initialization
        if weight_init == 'xavier':
            nn.init.xavier_uniform_(self.conv1.weight)
            nn.init.xavier_uniform_(self.conv2.weight)
            nn.init.xavier_uniform_(self.fc1.weight)
            nn.init.xavier_uniform_(self.fc2.weight)
        elif weight_init == 'kaiming':
            nn.init.kaiming_uniform_(self.conv1.weight, mode='fan_in', nonlinearity='relu')
            nn.init.kaiming_uniform_(self.conv2.weight, mode='fan_in', nonlinearity='relu')
            nn.init.kaiming_uniform_(self.fc1.weight, mode='fan_in', nonlinearity='relu')
            nn.init.kaiming_uniform_(self.fc2.weight, mode='fan_in', nonlinearity='relu')
        elif weight_init == 'random':
            nn.init.uniform_(self.conv1.weight)
            nn.init.uniform_(self.conv2.weight)
            nn.init.uniform_(self.fc1.weight)
            nn.init.uniform_(self.fc2.weight)
        
        self.activation_func = activation_func

    def forward(self, x):
        x = self.conv1(x)
        x = self.activation_func(x)
        x = F.max_pool2d(x, 2)
        x = self.conv2(x)
        x = self.activation_func(x)
        x = F.max_pool2d(x, 2)
        x = x.view(-1, 64 * 8 * 8)  # Adjusted for 32x32 input
        x = self.fc1(x)
        x = self.activation_func(x)
        x = self.fc2(x)
        return x

activation_functions = {
    'relu': nn.ReLU(),
    'tanh': nn.Tanh(),
    'leaky_relu': nn.LeakyReLU(0.1)
}

# Step 5: Define the Training Function
def train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs=10, config_name=None):
    model = model.to(device)
    best_accuracy = 0.0
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        val_accuracy = 100 * correct / total
        print(f'Epoch {epoch+1}, Loss: {running_loss/len(train_loader)}, Val Loss: {val_loss/len(val_loader)}, Val Acc: {val_accuracy}')

        if val_accuracy > best_accuracy:
            best_accuracy = val_accuracy
            best_model_state = model.state_dict()

    if best_model_state is not None:
        best_model_path = f'/kaggle/working/{config_name}_best.pth'
        torch.save(best_model_state, best_model_path)
        print(f'Best model for {config_name} saved at {best_model_path} with accuracy: {best_accuracy}')

    return best_accuracy

# Step 6: Redirect Output and Train the Model
class Tee:
    def __init__(self, *files):
        self.files = files

    def write(self, obj):
        for f in self.files:
            f.write(obj)

    def flush(self):
        for f in self.files:
            f.flush()

# Save the original sys.stdout
original_stdout = sys.stdout

# Open the output file
output_file = open('/kaggle/working/training_log.txt', 'w')

# Redirect stdout to both the file and the notebook
sys.stdout = Tee(sys.stdout, output_file)

best_accuracy_all = 0.0
best_config_all = None
best_model_all = None

criterion = nn.CrossEntropyLoss()

for activation_name, activation_func in activation_functions.items():
    for weight_init in ['xavier', 'kaiming', 'random']:
        for optimizer_name in ['SGD', 'Adam', 'RMSprop']:
            config_name = f'{activation_name}_{weight_init}_{optimizer_name}'
            print(f'\nTraining with {config_name}')
            model = CNN(activation_func, weight_init)
            if optimizer_name == 'SGD':
                optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
            elif optimizer_name == 'Adam':
                optimizer = optim.Adam(model.parameters(), lr=0.001)
            elif optimizer_name == 'RMSprop':
                optimizer = optim.RMSprop(model.parameters(), lr=0.001)

            best_accuracy = train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs=10, config_name=config_name)

            if best_accuracy > best_accuracy_all:
                best_accuracy_all = best_accuracy
                best_config_all = config_name
                best_model_all = model.state_dict()

# Restore original stdout
sys.stdout = original_stdout
output_file.close()

print(f'Best overall accuracy: {best_accuracy_all} with configuration: {best_config_all}')
# Out:
# Using device: cuda
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:05<00:00, 31.8MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
#
# Training with relu_xavier_SGD
# Epoch 1, Loss: 1.8668865752037225, Val Loss: 1.619702493088155, Val Acc: 42.88
# Epoch 2, Loss: 1.4994408264184547, Val Loss: 1.3960141652747045, Val Acc: 50.7
# Epoch 3, Loss: 1.341345333992063, Val Loss: 1.3300545321235173, Val Acc: 52.7
# Epoch 4, Loss: 1.2525737957881236, Val Loss: 1.2322311642803723, Val Acc: 56.39
# Epoch 5, Loss: 1.1876769512510665, Val Loss: 1.1736443321916121, Val Acc: 58.85
# Epoch 6, Loss: 1.128165486676004, Val Loss: 1.1349170155163053, Val Acc: 60.07
# Epoch 7, Loss: 1.0775853587538384, Val Loss: 1.0988043410868584, Val Acc: 61.65
# Epoch 8, Loss: 1.0337715613872498, Val Loss: 1.0920892516268959, Val Acc: 61.48
# Epoch 9, Loss: 0.991312546955655, Val Loss: 1.0294663476038584, Val Acc: 64.19
# Epoch 10, Loss: 0.9528283347254214, Val Loss: 1.0143030225476133, Val Acc: 64.48
# Best model for relu_xavier_SGD saved at /kaggle/working/relu_xavier_SGD_best.pth with accuracy: 64.48
#
# Training with relu_xavier_Adam
# Epoch 1, Loss: 1.3702454446526744, Val Loss: 1.0764416561851018, Val Acc: 62.13
# Epoch 2, Loss: 0.9936775556000907, Val Loss: 0.9624459668050839, Val Acc: 66.2
# Epoch 3, Loss: 0.8436474851939989, Val Loss: 0.8922322928150997, Val Acc: 68.9
# Epoch 4, Loss: 0.7413019661403373, Val Loss: 0.8582131032702289, Val Acc: 70.45
# Epoch 5, Loss: 0.6547760225622855, Val Loss: 0.8330723628213134, Val Acc: 71.64
# Epoch 6, Loss: 0.5812965485903309, Val Loss: 0.8326313963419274, Val Acc: 72.33
# Epoch 7, Loss: 0.5138947850145648, Val Loss: 0.8776406110087528, Val Acc: 71.55
# Epoch 8, Loss: 0.45295731528945593, Val Loss: 0.8993190255346177, Val Acc: 71.69
# Epoch 9, Loss: 0.38378927729013934, Val Loss: 0.9768485223190694, Val Acc: 71.4
# Epoch 10, Loss: 0.3315735593857363, Val Loss: 0.9796080913724778, Val Acc: 72.03
# Best model for relu_xavier_Adam saved at /kaggle/working/relu_xavier_Adam_best.pth with accuracy: 72.33
#
# Training with relu_xavier_RMSprop
# Epoch 1, Loss: 1.4463610743622646, Val Loss: 1.1765150359914274, Val Acc: 58.53
# Epoch 2, Loss: 1.0138759786820473, Val Loss: 1.0468583869028696, Val Acc: 63.31
# Epoch 3, Loss: 0.8452645749082346, Val Loss: 0.9282786446281627, Val Acc: 67.46
# Epoch 4, Loss: 0.7200012832803799, Val Loss: 0.8895537890965426, Val Acc: 69.45
# Epoch 5, Loss: 0.6105073045586686, Val Loss: 0.8547899768322329, Val Acc: 71.1
# Epoch 6, Loss: 0.5063942428440085, Val Loss: 1.0230475098271914, Val Acc: 67.88
# Epoch 7, Loss: 0.4104986955290255, Val Loss: 0.8954409745675099, Val Acc: 71.39
# Epoch 8, Loss: 0.3226210055753703, Val Loss: 1.000597985484932, Val Acc: 71.4
# Epoch 9, Loss: 0.24834607229055955, Val Loss: 1.2067049953001965, Val Acc: 69.1
# Epoch 10, Loss: 0.18637587688386897, Val Loss: 1.2334258639359776, Val Acc: 70.1
# Best model for relu_xavier_RMSprop saved at /kaggle/working/relu_xavier_RMSprop_best.pth with accuracy: 71.4
#
# Training with relu_kaiming_SGD
# Epoch 1, Loss: 1.7455806643761638, Val Loss: 1.46440768543678, Val Acc: 47.81
# Epoch 2, Loss: 1.3732411910200972, Val Loss: 1.3031099129326735, Val Acc: 53.62
# Epoch 3, Loss: 1.2292824736641497, Val Loss: 1.2268661886830874, Val Acc: 56.05
# Epoch 4, Loss: 1.1456945820537674, Val Loss: 1.1842273662361917, Val Acc: 57.58
# Epoch 5, Loss: 1.070327206036014, Val Loss: 1.1097814455817017, Val Acc: 60.53
# Epoch 6, Loss: 1.0084547809017894, Val Loss: 1.0633092650884315, Val Acc: 62.34
# Epoch 7, Loss: 0.9626854880691489, Val Loss: 1.0468136902096905, Val Acc: 62.45
# Epoch 8, Loss: 0.9164252101307939, Val Loss: 1.005080504507958, Val Acc: 64.68
# Epoch 9, Loss: 0.8773984840458922, Val Loss: 0.9958950039706652, Val Acc: 64.98
# Epoch 10, Loss: 0.842554574884722, Val Loss: 0.9949297603172592, Val Acc: 65.32
# Best model for relu_kaiming_SGD saved at /kaggle/working/relu_kaiming_SGD_best.pth with accuracy: 65.32
#
# Training with relu_kaiming_Adam
# Epoch 1, Loss: 1.6031699778173891, Val Loss: 1.1775337178495866, Val Acc: 59.29
# Epoch 2, Loss: 1.0608804637513807, Val Loss: 1.0300765784480903, Val Acc: 63.56
# Epoch 3, Loss: 0.9058039148750208, Val Loss: 0.9547749908664559, Val Acc: 67.02
# Epoch 4, Loss: 0.7828289520405137, Val Loss: 0.9211930700495273, Val Acc: 68.41
# Epoch 5, Loss: 0.6862696353584299, Val Loss: 0.9141937184937393, Val Acc: 68.89
# Epoch 6, Loss: 0.6007776595747379, Val Loss: 0.9458719967286798, Val Acc: 68.49
# Epoch 7, Loss: 0.5222714820786205, Val Loss: 0.9748133443578889, Val Acc: 69.47
# Epoch 8, Loss: 0.4444279733978574, Val Loss: 1.008936869192727, Val Acc: 68.74
# Epoch 9, Loss: 0.3721050915434537, Val Loss: 1.1091280662560765, Val Acc: 67.87
# Epoch 10, Loss: 0.30855167826728136, Val Loss: 1.1839608406718773, Val Acc: 68.58
# Best model for relu_kaiming_Adam saved at /kaggle/working/relu_kaiming_Adam_best.pth with accuracy: 69.47
#
# Training with relu_kaiming_RMSprop
# Epoch 1, Loss: 1.8771291974255495, Val Loss: 1.2297331109831604, Val Acc: 56.19
# Epoch 2, Loss: 1.1215632496892338, Val Loss: 1.065061312687548, Val Acc: 62.77
# Epoch 3, Loss: 0.916465269482654, Val Loss: 1.0413389334195777, Val Acc: 64.45
# Epoch 4, Loss: 0.7583139633278713, Val Loss: 0.9582290694683413, Val Acc: 67.23
# Epoch 5, Loss: 0.6152888456421435, Val Loss: 1.1264090643653386, Val Acc: 64.66
# Epoch 6, Loss: 0.498727970339758, Val Loss: 0.970713622207883, Val Acc: 68.54
# Epoch 7, Loss: 0.39169527952323485, Val Loss: 1.0207096134560019, Val Acc: 69.75
# Epoch 8, Loss: 0.30435558722909456, Val Loss: 1.217802470997919, Val Acc: 66.96
# Epoch 9, Loss: 0.2291098422254138, Val Loss: 1.2946510405480107, Val Acc: 68.21
# Epoch 10, Loss: 0.1716295501879414, Val Loss: 1.3591967481601088, Val Acc: 68.77
# Best model for relu_kaiming_RMSprop saved at /kaggle/working/relu_kaiming_RMSprop_best.pth with accuracy: 69.75
#
# Training with relu_random_SGD
# Epoch 1, Loss: 25755.79964667391, Val Loss: 2.302761811244337, Val Acc: 10.0
# Epoch 2, Loss: 2.3027905198314307, Val Loss: 2.302653695963606, Val Acc: 10.0
# Epoch 3, Loss: 2.302700856762469, Val Loss: 2.3026061752174476, Val Acc: 10.0
# Epoch 4, Loss: 2.302650118118052, Val Loss: 2.3025887163379526, Val Acc: 10.0
# Epoch 5, Loss: 2.30263456176309, Val Loss: 2.3025801362870615, Val Acc: 10.0
# Epoch 6, Loss: 2.302629815343091, Val Loss: 2.302578126327901, Val Acc: 10.0
# Epoch 7, Loss: 2.302618903577175, Val Loss: 2.302581328379957, Val Acc: 10.0
# Epoch 8, Loss: 2.3026176029458987, Val Loss: 2.3025800548022306, Val Acc: 10.0
# Epoch 9, Loss: 2.302618826746636, Val Loss: 2.302581485313705, Val Acc: 10.0
# Epoch 10, Loss: 2.3026209950751966, Val Loss: 2.3025847145273715, Val Acc: 10.0
# Best model for relu_random_SGD saved at /kaggle/working/relu_random_SGD_best.pth with accuracy: 10.0
#
# Training with relu_random_Adam
# Epoch 1, Loss: 780615.718310422, Val Loss: 52310.22725474684, Val Acc: 16.67
# Epoch 2, Loss: 77306.33212615889, Val Loss: 114435.61906645569, Val Acc: 10.48
# Epoch 3, Loss: 64788.61098345588, Val Loss: 46507.95000988924, Val Acc: 16.03
# Epoch 4, Loss: 55827.198004915284, Val Loss: 68627.02892602848, Val Acc: 15.04
# Epoch 5, Loss: 42663.81454303868, Val Loss: 42925.78125, Val Acc: 13.86
# Epoch 6, Loss: 30008.529911285168, Val Loss: 27436.941332080696, Val Acc: 14.45
# Epoch 7, Loss: 23120.1105688539, Val Loss: 24180.14917919304, Val Acc: 16.37
# Epoch 8, Loss: 15937.395652673433, Val Loss: 13644.722396657437, Val Acc: 15.27
# Epoch 9, Loss: 11309.310573099825, Val Loss: 7452.733552956883, Val Acc: 12.66
# Epoch 10, Loss: 7210.965330158048, Val Loss: 5956.281095480617, Val Acc: 12.18
# Best model for relu_random_Adam saved at /kaggle/working/relu_random_Adam_best.pth with accuracy: 16.67
#
# Training with relu_random_RMSprop
# Epoch 1, Loss: 427587.7229060102, Val Loss: 151321.70856408228, Val Acc: 14.89
# Epoch 2, Loss: 58397.611356847425, Val Loss: 10524.347915842563, Val Acc: 14.17
# Epoch 3, Loss: 2662.6245745100327, Val Loss: 362.483389166337, Val Acc: 15.59
# Epoch 4, Loss: 116.17351341735372, Val Loss: 31.657963957967638, Val Acc: 15.99
# Epoch 5, Loss: 10.838782066579364, Val Loss: 3.9422720776328557, Val Acc: 12.52
# Epoch 6, Loss: 3.0542056139777687, Val Loss: 2.4651046493385413, Val Acc: 11.09
# Epoch 7, Loss: 2.440847984055424, Val Loss: 2.325933070122441, Val Acc: 9.89
# Epoch 8, Loss: 2.3652155124927727, Val Loss: 2.328855882717084, Val Acc: 10.58
# Epoch 9, Loss: 2.3195401786843224, Val Loss: 2.2892810966395123, Val Acc: 13.35
# Epoch 10, Loss: 2.2663725111490627, Val Loss: 2.223107259484786, Val Acc: 16.02
# Best model for relu_random_RMSprop saved at /kaggle/working/relu_random_RMSprop_best.pth with accuracy: 16.02
#
# Training with tanh_xavier_SGD
# Epoch 1, Loss: 1.7610857944049494, Val Loss: 1.5561485999747167, Val Acc: 45.71
# Epoch 2, Loss: 1.4825716552222172, Val Loss: 1.409365021729771, Val Acc: 50.22
# Epoch 3, Loss: 1.3514539881435501, Val Loss: 1.3018525853941711, Val Acc: 54.42
# Epoch 4, Loss: 1.2512973440272728, Val Loss: 1.2364901009994218, Val Acc: 56.0
# Epoch 5, Loss: 1.1790041842728929, Val Loss: 1.1706423374670971, Val Acc: 58.7
# Epoch 6, Loss: 1.1222366686062435, Val Loss: 1.137912068185927, Val Acc: 59.87
# Epoch 7, Loss: 1.076658931382172, Val Loss: 1.0876093257831623, Val Acc: 61.76
# Epoch 8, Loss: 1.0360859931277497, Val Loss: 1.0580649941782407, Val Acc: 63.14
# Epoch 9, Loss: 0.9972425292215079, Val Loss: 1.0279116404207447, Val Acc: 64.48
# Epoch 10, Loss: 0.9644770478958364, Val Loss: 1.0048128351380554, Val Acc: 64.71
# Best model for tanh_xavier_SGD saved at /kaggle/working/tanh_xavier_SGD_best.pth with accuracy: 64.71
#
# Training with tanh_xavier_Adam
# Epoch 1, Loss: 1.3011696677073799, Val Loss: 1.0735885546177248, Val Acc: 62.52
# Epoch 2, Loss: 0.9593729247217593, Val Loss: 0.949578898616984, Val Acc: 66.75
# Epoch 3, Loss: 0.8082450852369714, Val Loss: 0.92252344949336, Val Acc: 67.35
# Epoch 4, Loss: 0.6876081687867489, Val Loss: 0.883890800838229, Val Acc: 69.34
# Epoch 5, Loss: 0.5729130094161119, Val Loss: 0.9083756404586986, Val Acc: 69.09
# Epoch 6, Loss: 0.464991106401624, Val Loss: 0.9355425962918922, Val Acc: 68.66
# Epoch 7, Loss: 0.36561006715383065, Val Loss: 0.9673687989198709, Val Acc: 68.2
# Epoch 8, Loss: 0.27807730943193215, Val Loss: 1.018317863911013, Val Acc: 68.44
# Epoch 9, Loss: 0.2032338748769382, Val Loss: 1.0567619838292086, Val Acc: 68.4
# Epoch 10, Loss: 0.13971669971942902, Val Loss: 1.087826383264759, Val Acc: 69.13
# Best model for tanh_xavier_Adam saved at /kaggle/working/tanh_xavier_Adam_best.pth with accuracy: 69.34
#
# Training with tanh_xavier_RMSprop
# Epoch 1, Loss: 1.5475032285351278, Val Loss: 1.2789765898185441, Val Acc: 54.68
# Epoch 2, Loss: 1.050532095420086, Val Loss: 1.0200698994383026, Val Acc: 63.99
# Epoch 3, Loss: 0.8700195683542725, Val Loss: 0.972320102438142, Val Acc: 66.52
# Epoch 4, Loss: 0.7430539986361628, Val Loss: 1.0401065221315697, Val Acc: 63.61
# Epoch 5, Loss: 0.6262037438504836, Val Loss: 0.9607901460007776, Val Acc: 67.31
# Epoch 6, Loss: 0.5242541337104709, Val Loss: 0.9333629306358627, Val Acc: 68.49
# Epoch 7, Loss: 0.42943257794660683, Val Loss: 0.9869601409646529, Val Acc: 67.53
# Epoch 8, Loss: 0.33935477773246864, Val Loss: 0.9980929252467577, Val Acc: 68.26
# Epoch 9, Loss: 0.26530470697166364, Val Loss: 1.0435148454919647, Val Acc: 67.59
# Epoch 10, Loss: 0.20710255319962417, Val Loss: 1.0872174018545995, Val Acc: 68.43
# Best model for tanh_xavier_RMSprop saved at /kaggle/working/tanh_xavier_RMSprop_best.pth with accuracy: 68.49
#
# Training with tanh_kaiming_SGD
# Epoch 1, Loss: 1.7080707614074278, Val Loss: 1.5062301626688317, Val Acc: 47.1
# Epoch 2, Loss: 1.4219322043001805, Val Loss: 1.3822722917870631, Val Acc: 51.02
# Epoch 3, Loss: 1.301250990089553, Val Loss: 1.2774655290796786, Val Acc: 54.65
# Epoch 4, Loss: 1.2170461817165774, Val Loss: 1.2158293829688542, Val Acc: 56.91
# Epoch 5, Loss: 1.1492682515507768, Val Loss: 1.1680527638785447, Val Acc: 58.85
# Epoch 6, Loss: 1.08957438182343, Val Loss: 1.1145691728290124, Val Acc: 61.16
# Epoch 7, Loss: 1.0378266286362163, Val Loss: 1.0810181377809258, Val Acc: 61.72
# Epoch 8, Loss: 0.9922623966660951, Val Loss: 1.0504158984256695, Val Acc: 62.65
# Epoch 9, Loss: 0.9505534995242458, Val Loss: 1.026321988317031, Val Acc: 63.46
# Epoch 10, Loss: 0.9169914780370415, Val Loss: 1.0002089059805568, Val Acc: 64.72
# Best model for tanh_kaiming_SGD saved at /kaggle/working/tanh_kaiming_SGD_best.pth with accuracy: 64.72
#
# Training with tanh_kaiming_Adam
# Epoch 1, Loss: 1.3416958995487378, Val Loss: 1.0999045839792565, Val Acc: 60.52
# Epoch 2, Loss: 0.9456851525074991, Val Loss: 0.9616494020329246, Val Acc: 66.26
# Epoch 3, Loss: 0.7596243961387888, Val Loss: 0.9166232815271691, Val Acc: 68.19
# Epoch 4, Loss: 0.6160194971372405, Val Loss: 0.9659615687177151, Val Acc: 66.76
# Epoch 5, Loss: 0.4901224114858281, Val Loss: 0.9522419164452371, Val Acc: 67.98
# Epoch 6, Loss: 0.37084844132975847, Val Loss: 0.9815919406806366, Val Acc: 67.66
# Epoch 7, Loss: 0.2668875354482695, Val Loss: 1.0316271382042124, Val Acc: 67.88
# Epoch 8, Loss: 0.19006197688067356, Val Loss: 1.0879156151904334, Val Acc: 67.34
# Epoch 9, Loss: 0.12395956493018533, Val Loss: 1.1057484165022644, Val Acc: 67.73
# Epoch 10, Loss: 0.08296253506446738, Val Loss: 1.1925702291198923, Val Acc: 67.28
# Best model for tanh_kaiming_Adam saved at /kaggle/working/tanh_kaiming_Adam_best.pth with accuracy: 68.19
#
# Training with tanh_kaiming_RMSprop
# Epoch 1, Loss: 1.4876422778419827, Val Loss: 1.1784920277474802, Val Acc: 58.09
# Epoch 2, Loss: 1.0398336894371931, Val Loss: 1.050619514682625, Val Acc: 62.58
# Epoch 3, Loss: 0.8594702617896487, Val Loss: 0.9359221496159518, Val Acc: 66.72
# Epoch 4, Loss: 0.7291095220981656, Val Loss: 0.9336439001409313, Val Acc: 67.36
# Epoch 5, Loss: 0.609781496665057, Val Loss: 0.9484446818315531, Val Acc: 67.53
# Epoch 6, Loss: 0.5026119292697029, Val Loss: 0.9611383487906637, Val Acc: 67.29
# Epoch 7, Loss: 0.40409915614158604, Val Loss: 1.0733096939098985, Val Acc: 65.34
# Epoch 8, Loss: 0.3192193223082501, Val Loss: 1.026053765152074, Val Acc: 67.75
# Epoch 9, Loss: 0.24859883302770308, Val Loss: 1.139678089679042, Val Acc: 65.66
# Epoch 10, Loss: 0.18879860267995874, Val Loss: 1.1496227270440211, Val Acc: 66.72
# Best model for tanh_kaiming_RMSprop saved at /kaggle/working/tanh_kaiming_RMSprop_best.pth with accuracy: 67.75
#
# Training with tanh_random_SGD
# Epoch 1, Loss: 2.4179296334991065, Val Loss: 2.3244350922258596, Val Acc: 12.86
# Epoch 2, Loss: 2.3222449161207583, Val Loss: 2.315461744236041, Val Acc: 12.93
# Epoch 3, Loss: 2.3183173822320025, Val Loss: 2.310184554208683, Val Acc: 12.86
# Epoch 4, Loss: 2.314011414032763, Val Loss: 2.3099916252908828, Val Acc: 12.88
# Epoch 5, Loss: 2.3113549359314276, Val Loss: 2.30725587470622, Val Acc: 12.88
# Epoch 6, Loss: 2.3088553872559685, Val Loss: 2.3066483902025827, Val Acc: 12.45
# Epoch 7, Loss: 2.3058480021288936, Val Loss: 2.3076209267483483, Val Acc: 12.86
# Epoch 8, Loss: 2.30444804176955, Val Loss: 2.306402130971981, Val Acc: 12.84
# Epoch 9, Loss: 2.3032579653708223, Val Loss: 2.3045296729365483, Val Acc: 12.93
# Epoch 10, Loss: 2.301171704021561, Val Loss: 2.304432543018196, Val Acc: 11.91
# Best model for tanh_random_SGD saved at /kaggle/working/tanh_random_SGD_best.pth with accuracy: 12.93
#
# Training with tanh_random_Adam
# Epoch 1, Loss: 2.473819136924451, Val Loss: 2.309098104887371, Val Acc: 13.0
# Epoch 2, Loss: 2.313504627598521, Val Loss: 2.309946570215346, Val Acc: 12.02
# Epoch 3, Loss: 2.309820993477121, Val Loss: 2.3097056769117525, Val Acc: 13.32
# Epoch 4, Loss: 2.3068999494128213, Val Loss: 2.313512714603279, Val Acc: 13.06
# Epoch 5, Loss: 2.3076980083494845, Val Loss: 2.305063286914101, Val Acc: 13.6
# Epoch 6, Loss: 2.3044495795998734, Val Loss: 2.311469754086265, Val Acc: 12.78
# Epoch 7, Loss: 2.2982137867861696, Val Loss: 2.310029183761983, Val Acc: 13.37
# Epoch 8, Loss: 2.298360077011616, Val Loss: 2.313684348818622, Val Acc: 13.04
# Epoch 9, Loss: 2.296033815349764, Val Loss: 2.307320130022266, Val Acc: 13.73
# Epoch 10, Loss: 2.2929518308176102, Val Loss: 2.31513854823535, Val Acc: 13.67
# Best model for tanh_random_Adam saved at /kaggle/working/tanh_random_Adam_best.pth with accuracy: 13.73
#
# Training with tanh_random_RMSprop
# Epoch 1, Loss: 2.3340641397344486, Val Loss: 2.3140358291094816, Val Acc: 11.52
# Epoch 2, Loss: 2.3122616795932545, Val Loss: 2.3227072426035433, Val Acc: 12.15
# Epoch 3, Loss: 2.3115364651545844, Val Loss: 2.3220068140874934, Val Acc: 12.76
# Epoch 4, Loss: 2.30585571871999, Val Loss: 2.328973151460479, Val Acc: 12.65
# Epoch 5, Loss: 2.304404741053081, Val Loss: 2.3163592151448698, Val Acc: 12.65
# Epoch 6, Loss: 2.3054253774530746, Val Loss: 2.318653665011442, Val Acc: 12.94
# Epoch 7, Loss: 2.3007950435209152, Val Loss: 2.3185550442224816, Val Acc: 13.44
# Epoch 8, Loss: 2.300011442140545, Val Loss: 2.322117835660524, Val Acc: 12.57
# Epoch 9, Loss: 2.2987129913876427, Val Loss: 2.315386651437494, Val Acc: 12.84
# Epoch 10, Loss: 2.2956724679073712, Val Loss: 2.325294995609718, Val Acc: 12.24
# Best model for tanh_random_RMSprop saved at /kaggle/working/tanh_random_RMSprop_best.pth with accuracy: 13.44
#
# Training with leaky_relu_xavier_SGD
# Epoch 1, Loss: 1.8639515330419516, Val Loss: 1.6122685504865042, Val Acc: 44.24
# Epoch 2, Loss: 1.4898101237728774, Val Loss: 1.373428442810155, Val Acc: 51.28
# Epoch 3, Loss: 1.320401299944924, Val Loss: 1.2759681170499777, Val Acc: 54.44
# Epoch 4, Loss: 1.2283489100463556, Val Loss: 1.2010984013352213, Val Acc: 57.88
# Epoch 5, Loss: 1.1625041100375182, Val Loss: 1.1612442279163795, Val Acc: 59.28
# Epoch 6, Loss: 1.1043262596020613, Val Loss: 1.1328141289421274, Val Acc: 59.4
# Epoch 7, Loss: 1.0566607715223757, Val Loss: 1.095670314529274, Val Acc: 61.75
# Epoch 8, Loss: 1.0105114849022283, Val Loss: 1.0428500394277935, Val Acc: 63.4
# Epoch 9, Loss: 0.9753656100738993, Val Loss: 1.0354743826238415, Val Acc: 63.43
# Epoch 10, Loss: 0.9404266583340247, Val Loss: 1.0266152688219576, Val Acc: 64.63
# Best model for leaky_relu_xavier_SGD saved at /kaggle/working/leaky_relu_xavier_SGD_best.pth with accuracy: 64.63
#
# Training with leaky_relu_xavier_Adam
# Epoch 1, Loss: 1.2795129174466633, Val Loss: 1.0231800856469553, Val Acc: 63.59
# Epoch 2, Loss: 0.8958987172912148, Val Loss: 0.8936764416815359, Val Acc: 68.79
# Epoch 3, Loss: 0.7350621973462117, Val Loss: 0.8216463651838182, Val Acc: 71.67
# Epoch 4, Loss: 0.6052595087329445, Val Loss: 0.8332050412516051, Val Acc: 71.78
# Epoch 5, Loss: 0.48685350282417844, Val Loss: 0.844460540934454, Val Acc: 72.78
# Epoch 6, Loss: 0.3760855844639756, Val Loss: 0.9190066237992878, Val Acc: 72.02
# Epoch 7, Loss: 0.27880248099641725, Val Loss: 1.0069127761864964, Val Acc: 72.11
# Epoch 8, Loss: 0.19933873077716363, Val Loss: 1.1068539777888526, Val Acc: 71.06
# Epoch 9, Loss: 0.14152706407791818, Val Loss: 1.2328610699388045, Val Acc: 71.34
# Epoch 10, Loss: 0.10522285640201605, Val Loss: 1.345817454253571, Val Acc: 71.41
# Best model for leaky_relu_xavier_Adam saved at /kaggle/working/leaky_relu_xavier_Adam_best.pth with accuracy: 72.78
#
# Training with leaky_relu_xavier_RMSprop
# Epoch 1, Loss: 1.3704872492634121, Val Loss: 1.1145337216461761, Val Acc: 59.99
# Epoch 2, Loss: 0.9065383691007219, Val Loss: 0.9121011261698566, Val Acc: 67.91
# Epoch 3, Loss: 0.7407219929768302, Val Loss: 0.8372186829772177, Val Acc: 70.65
# Epoch 4, Loss: 0.6053965355429198, Val Loss: 0.8843171332455888, Val Acc: 69.65
# Epoch 5, Loss: 0.4842843305119468, Val Loss: 0.8837864979912963, Val Acc: 70.59
# Epoch 6, Loss: 0.38068727146634057, Val Loss: 0.9129801196388051, Val Acc: 71.76
# Epoch 7, Loss: 0.28901223049444313, Val Loss: 1.0103128318545185, Val Acc: 71.5
# Epoch 8, Loss: 0.21426310359745684, Val Loss: 1.1100811437715459, Val Acc: 71.64
# Epoch 9, Loss: 0.15917987219246146, Val Loss: 1.3045235615742357, Val Acc: 70.24
# Epoch 10, Loss: 0.12257961098990781, Val Loss: 1.382039673720734, Val Acc: 70.7
# Best model for leaky_relu_xavier_RMSprop saved at /kaggle/working/leaky_relu_xavier_RMSprop_best.pth with accuracy: 71.76
#
# Training with leaky_relu_kaiming_SGD
# Epoch 1, Loss: 1.6960354400107929, Val Loss: 1.4438700766503056, Val Acc: 48.61
# Epoch 2, Loss: 1.3485467011666359, Val Loss: 1.2971918598006043, Val Acc: 53.91
# Epoch 3, Loss: 1.2086057219358965, Val Loss: 1.200508912907371, Val Acc: 57.3
# Epoch 4, Loss: 1.1146860817814117, Val Loss: 1.1288435685483715, Val Acc: 60.4
# Epoch 5, Loss: 1.0433358934224415, Val Loss: 1.091078368923332, Val Acc: 61.8
# Epoch 6, Loss: 0.985027954554009, Val Loss: 1.0475624022604544, Val Acc: 63.44
# Epoch 7, Loss: 0.935106320301895, Val Loss: 1.0404470185690289, Val Acc: 63.67
# Epoch 8, Loss: 0.8912549689602669, Val Loss: 1.0243288384208196, Val Acc: 64.8
# Epoch 9, Loss: 0.8526399585292163, Val Loss: 0.9970016766198074, Val Acc: 65.6
# Epoch 10, Loss: 0.8166196202987905, Val Loss: 0.9967361017118527, Val Acc: 65.63
# Best model for leaky_relu_kaiming_SGD saved at /kaggle/working/leaky_relu_kaiming_SGD_best.pth with accuracy: 65.63
#
# Training with leaky_relu_kaiming_Adam
# Epoch 1, Loss: 1.5006440179732146, Val Loss: 1.0852034967156905, Val Acc: 61.31
# Epoch 2, Loss: 0.9600111828435718, Val Loss: 0.9997696997244147, Val Acc: 65.13
# Epoch 3, Loss: 0.7799177229252008, Val Loss: 0.9426432244385345, Val Acc: 67.52
# Epoch 4, Loss: 0.6373344937248913, Val Loss: 0.8979258341125295, Val Acc: 70.09
# Epoch 5, Loss: 0.5120021039262757, Val Loss: 0.944615329368205, Val Acc: 68.62
# Epoch 6, Loss: 0.3973427015497252, Val Loss: 0.9812941770010357, Val Acc: 69.18
# Epoch 7, Loss: 0.29514577565595623, Val Loss: 1.1052641506436505, Val Acc: 69.02
# Epoch 8, Loss: 0.22196479559020924, Val Loss: 1.1914037737665297, Val Acc: 68.87
# Epoch 9, Loss: 0.16114587957977944, Val Loss: 1.2936649367779116, Val Acc: 69.87
# Epoch 10, Loss: 0.11993695816496754, Val Loss: 1.4271781618082071, Val Acc: 68.21
# Best model for leaky_relu_kaiming_Adam saved at /kaggle/working/leaky_relu_kaiming_Adam_best.pth with accuracy: 70.09
#
# Training with leaky_relu_kaiming_RMSprop
# Epoch 1, Loss: 1.9774698703490254, Val Loss: 1.1877374626413177, Val Acc: 57.99
# Epoch 2, Loss: 1.0413428153223394, Val Loss: 1.018566967565802, Val Acc: 64.72
# Epoch 3, Loss: 0.835188578156864, Val Loss: 0.9964379170272923, Val Acc: 66.25
# Epoch 4, Loss: 0.6557987059473687, Val Loss: 0.9674719277816483, Val Acc: 67.31
# Epoch 5, Loss: 0.4955595103676057, Val Loss: 1.018936843057222, Val Acc: 68.23
# Epoch 6, Loss: 0.36148672484223493, Val Loss: 1.107270749309395, Val Acc: 67.95
# Epoch 7, Loss: 0.2593295157832258, Val Loss: 1.2459180513514747, Val Acc: 67.65
# Epoch 8, Loss: 0.18416890031312738, Val Loss: 1.3926435377024398, Val Acc: 67.26
# Epoch 9, Loss: 0.1404695453222298, Val Loss: 1.499204457560672, Val Acc: 68.12
# Epoch 10, Loss: 0.10818459699525858, Val Loss: 1.5898679313780386, Val Acc: 68.28
# Best model for leaky_relu_kaiming_RMSprop saved at /kaggle/working/leaky_relu_kaiming_RMSprop_best.pth with accuracy: 68.28
#
# Training with leaky_relu_random_SGD
# Epoch 1, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Epoch 2, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Epoch 3, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Epoch 4, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Epoch 5, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Epoch 6, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Epoch 7, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Epoch 8, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Epoch 9, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Epoch 10, Loss: nan, Val Loss: nan, Val Acc: 10.0
# Best model for leaky_relu_random_SGD saved at /kaggle/working/leaky_relu_random_SGD_best.pth with accuracy: 10.0
#
# Training with leaky_relu_random_Adam
# Epoch 1, Loss: 493217.4443434303, Val Loss: 145586.07713607594, Val Acc: 12.78
# Epoch 2, Loss: 80289.1478880275, Val Loss: 49634.44714200949, Val Acc: 17.63
# Epoch 3, Loss: 54423.36381573689, Val Loss: 52039.13434533228, Val Acc: 13.36
# Epoch 4, Loss: 42069.143779471706, Val Loss: 24791.36466574367, Val Acc: 16.81
# Epoch 5, Loss: 31147.490381733536, Val Loss: 44019.98417721519, Val Acc: 12.48
# Epoch 6, Loss: 20998.061246203644, Val Loss: 15696.474287974683, Val Acc: 16.06
# Epoch 7, Loss: 13534.338272758152, Val Loss: 8729.039495154273, Val Acc: 16.67
# Epoch 8, Loss: 8872.422403867287, Val Loss: 8651.314712717563, Val Acc: 12.65
# Epoch 9, Loss: 5739.546848775176, Val Loss: 5241.347359572785, Val Acc: 11.93
# Epoch 10, Loss: 3444.491022992927, Val Loss: 1467.1508480023733, Val Acc: 19.4
# Best model for leaky_relu_random_Adam saved at /kaggle/working/leaky_relu_random_Adam_best.pth with accuracy: 19.4
#
# Training with leaky_relu_random_RMSprop
# Epoch 1, Loss: 463531.5603620524, Val Loss: 205250.03639240508, Val Acc: 10.09
# Epoch 2, Loss: 63591.12892872842, Val Loss: 10287.884067197389, Val Acc: 17.17
# Epoch 3, Loss: 3247.3805311744477, Val Loss: 309.1596235444274, Val Acc: 19.41
# Epoch 4, Loss: 104.59375636108086, Val Loss: 21.66741786425627, Val Acc: 19.19
# Epoch 5, Loss: 8.660719628224287, Val Loss: 4.553483848330341, Val Acc: 11.62
# Epoch 6, Loss: 3.272331887803724, Val Loss: 2.615102612519566, Val Acc: 19.63
# Epoch 7, Loss: 4.618806937161614, Val Loss: 4.637547052359279, Val Acc: 12.32
# Epoch 8, Loss: 4.385964968625237, Val Loss: 4.515189587315427, Val Acc: 15.74
# Epoch 9, Loss: 2.714877408788637, Val Loss: 2.372195421894894, Val Acc: 22.72
# Epoch 10, Loss: 2.2425198384258143, Val Loss: 2.233910343315028, Val Acc: 25.87
# Best model for leaky_relu_random_RMSprop saved at /kaggle/working/leaky_relu_random_RMSprop_best.pth with accuracy: 25.87
# Best overall accuracy: 72.78 with configuration: leaky_relu_xavier_Adam
